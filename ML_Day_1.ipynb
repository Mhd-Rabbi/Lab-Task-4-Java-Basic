# %% [markdown]
# <a href="https://colab.research.google.com/github/Mhd-Rabbi/Lab-Task-4-Java-Basic/blob/main/ML_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # import

# %%
from ultralytics import YOLO

# %% [markdown]
# #model declaration

# %%
model = YOLO('yolo11n.pt')

# %% [markdown]
# # model apply

# %%
model.predict(source="/content/15551422_1080_1920_30fps.mp4",save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/369) /content/15551422_1080_1920_30fps.mp4: 640x384 7 persons, 4 motorcycles, 57.2ms
# video 1/1 (frame 2/369) /content/15551422_1080_1920_30fps.mp4: 640x384 4 persons, 4 motorcycles, 13.2ms
# video 1/1 (frame 3/369) /content/15551422_1080_1920_30fps.mp4: 640x384 4 persons, 5 motorcycles, 11.9ms
# video 1/1 (frame 4/369) /content/15551422_1080_1920_30fps.mp4: 640x384 5 persons, 3 motorcycles, 13.5ms
# ...
